# %% [markdown]
# # Dart Target
#
# ## Description
#
# Detect the coordinates of this dart target center

# %% [markdown]
# ## Group ID
#
# Grupo 4
# Ana Sofia Ramos Oliveira - PG61510
# Maria Inês Barros de Matos - PG61533

# %%
import cv2
# to install cv2 use: pip install opencv-python
import matplotlib.pyplot as plt 
import numpy as np

# %%
fname = 'DartTarget-noisy.png'
img = cv2.imread(fname,cv2.IMREAD_GRAYSCALE)
W,H=img.shape
print(img.shape)
ratio=H/W
fig = plt.figure(figsize=(8,8*ratio))
plt.imshow(img, cmap='gray')
# Out:
# (708, 1052)
